# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Load the dataset

# %%
df = pd.read_csv('2015.csv')

df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %% [markdown]
# Check for Null Values

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140

# %%
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# drop the columns which are not contributing to target variable

# %%
df = df.drop(['Country','Region','Happiness Rank'],axis=1)

# %%
df.head(5)
# Out:
#    Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0            7.587         0.03411                   1.39651  1.34951
# 1            7.561         0.04884                   1.30232  1.40223
# 2            7.527         0.03328                   1.32548  1.36058
# 3            7.522         0.03880                   1.45900  1.33095
# 4            7.427         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %% [markdown]
# # Target Variable

# %%
sns.distplot(df['Happiness Score']);

# %% [markdown]
# # Feature Distribution of Dataset

# %%
plt.figure(figsize=(30,30),facecolor='orange')
pn = 1

for column in df:
    if pn <= 10:
        ax = plt.subplot(5,2,pn)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    pn +=1
plt.tight_layout()

# %%
df.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # Outliers

# %%
plt.figure(figsize=(30,30),facecolor='pink')
pn = 1

for column in df:
    if pn <= 10:
        ax = plt.subplot(5,2,pn)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    pn +=1
plt.tight_layout()

# %%
print(df['Standard Error'].quantile(0.90))
print(df['Standard Error'].quantile(0.10))
# Out:
# 0.06791900000000002
# 0.033235

# %%
df['Standard Error'] = np.where(df['Standard Error'] > 0.067919000000000020,0.06791900000000002,df['Standard Error'])

# %%
sns.boxplot(df['Standard Error'])
# Out:
# <AxesSubplot: >

# %%
print(df['Family'].quantile(0.90))
print(df['Family'].quantile(0.10))
# Out:
# 1.291461
# 0.6204390000000001

# %%
df['Family'] = np.where(df['Family'] < 0.6204390000000001,0.6204390000000001,df['Family'])

# %%
sns.boxplot(df['Family'])
# Out:
# <AxesSubplot: >

# %%
print(df['Trust (Government Corruption)'].quantile(0.90))
print(df['Trust (Government Corruption)'].quantile(0.10))
# Out:
# 0.326539
# 0.028650000000000002

# %%
df['Trust (Government Corruption)'] = np.where(df['Trust (Government Corruption)'] > 0.326539,0.326539,df['Trust (Government Corruption)'])

# %%
sns.boxplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot: >

# %%
print(df['Generosity'].quantile(0.90))
print(df['Generosity'].quantile(0.10))
# Out:
# 0.4123720000000001
# 0.106185

# %%
df['Generosity'] = np.where(df['Generosity'] > 0.4123720000000002,0.4123720000000002,df['Generosity'])

# %%
sns.boxplot(df['Generosity'])
# Out:
# <AxesSubplot: >

# %%
print(df['Dystopia Residual'].quantile(0.90))
print(df['Dystopia Residual'].quantile(0.10))
# Out:
# 2.801197
# 1.456452

# %%
df['Dystopia Residual'] = np.where(df['Dystopia Residual'] > 2.801197,2.801197,df['Dystopia Residual'])
df['Dystopia Residual'] = np.where(df['Dystopia Residual'] < 1.456452,1.456452,df['Dystopia Residual'])

# %%
sns.boxplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(30,30),facecolor='yellow')
pn = 1

for column in df:
    if pn <= 10:
        ax = plt.subplot(5,2,pn)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    pn +=1
plt.tight_layout()

# %%
plt.figure(figsize=(30,30),facecolor='grey')
pn = 1

for column in df:
    if pn <= 10:
        ax = plt.subplot(5,2,pn)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    pn +=1
plt.tight_layout()

# %%
df.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   0.397984
# Economy (GDP per Capita)        -0.317575
# Family                          -0.315662
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.840656
# Generosity                       0.225235
# Dystopia Residual                0.107477
# dtype: float64

# %% [markdown]
# # Checking Correlation

# %%
df_corr = df.corr()
df_corr
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.234101
# Standard Error                       -0.234101        1.000000
# Economy (GDP per Capita)              0.780966       -0.231406
# Family                                0.762521       -0.187493
# Health (Life Expectancy)              0.724200       -0.329051
# Freedom                               0.568211       -0.179356
# Trust (Government Corruption)         0.404202       -0.161471
# Generosity                            0.198494       -0.087645
# Dystopia Residual                     0.523492        0.036948
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.762521
# Standard Error                                -0.231406 -0.187493
# Economy (GDP per Capita)                       1.000000  0.655945
# Family                                         0.655945  1.000000
# Health (Life Expectancy)                       0.816478  0.534044
# Freedom                                        0.370300  0.489420
# Trust (Government Corruption)                  0.300598  0.239101
# Generosity                                     0.002896  0.125085
# Dystopia Residual                              0.042180  0.173223
#
#                                Health (Life Expectancy)   Freedom  \
# Happiness Score                                0.724200  0.568211
# Standard Error                                -0.329051 -0.179356
# Economy (GDP per Capita)                       0.816478  0.370300
# Family                                         0.534044  0.489420
# Health (Life Expectancy)                       1.000000  0.360477
# Freedom                                        0.360477  1.000000
# Trust (Government Corruption)                  0.237250  0.490168
# Generosity                                     0.113554  0.403442
# Dystopia Residual                              0.033996  0.087234
#
#                                Trust (Government Corruption)  Generosity  \
# Happiness Score                                     0.404202    0.198494
# Standard Error                                     -0.161471   -0.087645
# Economy (GDP per Capita)                            0.300598    0.002896
# Family                                              0.239101    0.125085
# Health (Life Expectancy)                            0.237250    0.113554
# Freedom                                             0.490168    0.403442
# Trust (Government Corruption)                       1.000000    0.282263
# Generosity                                          0.282263    1.000000
# Dystopia Residual                                   0.026823   -0.025253
#
#                                Dystopia Residual
# Happiness Score                         0.523492
# Standard Error                          0.036948
# Economy (GDP per Capita)                0.042180
# Family                                  0.173223
# Health (Life Expectancy)                0.033996
# Freedom                                 0.087234
# Trust (Government Corruption)           0.026823
# Generosity                             -0.025253
# Dystopia Residual                       1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_corr,annot=True,fmt='0.2f',linecolor='black',linewidths=10);

# %% [markdown]
# X is our feature variables and y is our target variable

# %%
X = df.drop(['Happiness Score'],axis=1)
print(X)
y = df['Happiness Score']
print(y)
# Out:
#      Standard Error  Economy (GDP per Capita)    Family  \
# 0          0.034110                   1.39651  1.349510
# 1          0.048840                   1.30232  1.402230
# 2          0.033280                   1.32548  1.360580
# 3          0.038800                   1.45900  1.330950
# 4          0.035530                   1.32629  1.322610
# ..              ...                       ...       ...
# 153        0.034640                   0.22208  0.773700
# 154        0.036560                   0.28665  0.620439
# 155        0.050150                   0.66320  0.620439
# 156        0.067919                   0.01530  0.620439
# 157        0.067270                   0.20868  0.620439
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                       0.326539
# 1                     0.94784  0.62877                       0.141450
# 2                     0.87464  0.64938                       0.326539
# 3                     0.88521  0.66973                       0.326539
# 4                     0.90563  0.63297                       0.326539
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                       0.326539
# 154                   0.31910  0.48450                       0.080100
# 155                   0.72193  0.15684                       0.189060
# 156                   0.22396  0.11850                       0.100620
# 157                   0.28443  0.36453                       0.107310
#
#      Generosity  Dystopia Residual
# 0      0.296780           2.517380
# 1      0.412372           2.702010
# 2      0.341390           2.492040
# 3      0.346990           2.465310
# 4      0.412372           2.451760
# ..          ...                ...
# 153    0.226280           1.456452
# 154    0.182600           1.633280
# 155    0.412372           1.456452
# 156    0.197270           1.833020
# 157    0.166810           1.567260
#
# [158 rows x 8 columns]
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %% [markdown]
# Relationship between all feature variables with target variable

# %%
plt.figure(figsize=(20,14))
pn = 1

for column in X:
    if pn <= 8:
        ax = plt.subplot(4,2,pn)
        sns.scatterplot(column)        
    pn +=1
plt.tight_layout()

# %% [markdown]
# There were skewness in the feature variables we will transform it by using PowerTransfomer

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method='yeo-johnson')
x = pt.fit_transform(X)
x
# Out:
# array([[-1.019534  ,  1.44606101,  1.63571005, ...,  1.64073768,
#          0.68160602,  0.94102664],
#        [ 0.32263422,  1.17332111,  1.93730033, ...,  0.32751263,
#          1.63889967,  1.32547197],
#        [-1.10357471,  1.23983557,  1.69827202, ...,  1.64073768,
#          1.06435302,  0.88719009],
#        ...,
#        [ 0.42939622, -0.5134688 , -1.6285676 , ...,  0.78241282,
#          1.63889967, -1.58972433],
#        [ 1.70491151, -1.89495386, -1.6285676 , ..., -0.16024724,
#         -0.24078288, -0.61831801],
#        [ 1.66349969, -1.52122584, -1.6285676 , ..., -0.07308916,
#         -0.54426501, -1.29385524]])

# %%
#from sklearn.preprocessing import StandardScaler

#scaler = StandardScaler()

# %%
#X_scaled = scaler.fit_transform(X)

#X_scaled

# %% [markdown]
# Model building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=49)

# %%
x_train
# Out:
# array([[-1.31997356e-01, -1.39329041e+00, -1.31822223e+00,
#         -7.52829844e-01, -6.92129050e-03,  7.93228459e-01,
#          1.63889967e+00, -1.58972433e+00],
#        [-8.36631915e-01,  1.18908428e+00,  1.28275116e+00,
#          1.21605464e+00,  1.07435432e+00,  1.06496633e+00,
#          2.72939432e-03,  7.21503611e-01],
#        [-4.58994732e-02,  3.62165503e-01, -1.62856760e+00,
#          1.47199893e-01, -9.00187404e-01, -7.84155245e-01,
#          1.38880682e+00, -9.64977940e-01],
#        [-7.09218090e-01, -6.74504532e-01, -1.62856760e+00,
#         -6.34213525e-01, -1.83829247e+00, -1.07508149e-01,
#          1.02501932e+00,  1.52659456e+00],
#        [-2.08447188e+00,  5.14694624e-02, -3.70814961e-01,
#          7.55437142e-01,  5.47674101e-01, -1.34208511e+00,
#         -1.45114440e+00, -5.51229774e-01],
#        [-3.73447076e-01,  1.26318316e+00,  1.41148341e+00,
#          1.42981646e+00,  1.63177353e+00,  1.64073768e+00,
#          1.63889967e+00,  3.95691627e-01],
#        [-2.53639300e+00, -5.57094540e-01, -1.62856760e+00,
#         -6.31839720e-01, -2.92790417e-01, -3.77279154e-01,
#          3.95542864e-01,  4.15005281e-01],
#        [ 4.66435249e-01, -1.36386103e+00, -1.22909294e-01,
#         -1.08933486e+00, -7.30313869e-01, -8.03479457e-01,
#          1.08428437e+00, -1.58972433e+00],
#        [ 4.58403018e-01,  1.25120044e-01,  1.03948638e+00,
#          1.12583225e-01,  6.82066525e-01, -9.10084443e-01,
#         -3.71587466e-01,  1.52659456e+00],
#        [-7.53696593e-01, -1.92299897e+00, -1.29594264e-01,
#         -1.79883678e+00, -1.31608997e+00, -5.05137684e-01,
#          2.45127823e-01,  1.52659456e+00],
#        [ 1.63457352e+00, -4.76228089e-01, -1.48269803e+00,
#         -1.30060440e+00, -1.80928538e-01,  4.61692863e-02,
#         -9.90824969e-01, -9.98238069e-01],
#        [ 4.31818893e-01, -1.73838610e-01, -9.28802967e-01,
#         -1.58687921e-01, -1.20009191e+00, -9.76329697e-01,
#          5.60620148e-01,  1.45521710e+00],
#        [-9.62375849e-01,  9.68258742e-01,  1.43659928e+00,
#          1.58198072e+00,  1.28364631e-01, -6.96597778e-01,
#         -3.88900099e-01,  7.24236131e-02],
#        [ 1.35258509e+00,  2.33428411e+00,  2.29200807e-01,
#          6.50810512e-01,  1.53870175e+00,  1.64073768e+00,
#          9.31994892e-01, -1.32156393e+00],
#        [ 1.70491151e+00, -9.62004617e-01, -5.02490816e-01,
#         -1.33174021e+00,  3.34967741e-01,  1.39520320e-01,
#         -2.54107646e-01,  1.18604334e+00],
#        [ 7.41553345e-01,  1.23488345e+00,  9.14137880e-01,
#          3.88887296e-01,  9.59927962e-02,  1.54403279e+00,
#         -4.75484282e-01, -8.54726341e-01],
#        [ 3.43975595e-01,  5.08857036e-01,  8.22448677e-01,
#          6.46942061e-01,  7.39342779e-01, -2.67474901e-01,
#          2.08054483e-01,  1.52659456e+00],
#        [ 6.82318695e-01,  1.33996015e+00,  2.44535378e-01,
#          4.68682614e-01,  1.47352977e+00,  1.63487629e+00,
#         -6.49083091e-02,  8.50601526e-01],
#        [ 1.49990282e+00,  4.56911608e-01,  1.12312710e+00,
#          2.56006098e-01, -8.31854257e-02, -3.02007691e-02,
#         -1.71859377e+00,  1.52659456e+00],
#        [-9.60378472e-01,  9.63923978e-01,  9.54199792e-01,
#          1.32042238e+00, -1.90802767e-01, -4.81092759e-01,
#          9.82872828e-01,  1.52659456e+00],
#        [ 1.70491151e+00,  3.58999682e-01, -2.01384752e-01,
#          2.02272566e-01,  8.84182783e-01, -5.20878186e-01,
#          1.36119636e+00, -7.95809766e-01],
#        [-8.74024969e-01,  2.51308915e-01,  1.17162243e+00,
#          3.45224931e-01,  8.52573414e-01, -1.26299665e+00,
#          1.63889967e+00,  5.13190367e-01],
#        [ 1.70491151e+00, -1.76797654e+00, -1.54804108e-02,
#         -1.81178115e+00, -6.59400305e-01,  4.78446084e-01,
#          4.53716849e-03,  1.52659456e+00],
#        [ 5.30300853e-01, -9.73324539e-01, -1.08703780e+00,
#         -1.68964412e+00,  1.93389235e-01,  6.96972803e-01,
#         -1.98009150e-01, -1.58972433e+00],
#        [ 1.70491151e+00, -1.26882091e+00, -3.31751192e-01,
#         -1.97108893e+00, -2.22862949e-01, -3.35250140e-01,
#         -7.00891587e-02,  9.25565870e-01],
#        [ 2.04731770e-01, -7.90630505e-01, -1.42410971e+00,
#         -1.02878139e+00, -1.21741669e-01, -1.04523989e+00,
#          8.20053101e-02,  4.90541055e-01],
#        [-6.85163122e-01, -8.87160376e-02, -4.85128581e-02,
#          1.95304066e-01,  7.02031537e-01, -2.80085249e-01,
#          1.60685560e+00, -1.58972433e+00],
#        [ 1.70491151e+00,  6.93842081e-01,  4.22118664e-01,
#          1.74760313e-01, -1.67332793e-01, -3.59932844e-02,
#         -3.82130109e-01, -3.74582988e-03],
#        [ 1.67182369e+00, -8.46993055e-01, -7.13704547e-02,
#         -1.13054735e+00, -1.93022345e+00,  3.82097741e-01,
#         -3.06134201e-01,  2.65823724e-01],
#        [ 4.29396222e-01, -5.13468800e-01, -1.62856760e+00,
#          2.62933123e-01, -1.66865772e+00,  7.82412817e-01,
#          1.63889967e+00, -1.58972433e+00],
#        [-9.18560901e-01,  1.10323667e+00,  1.14670029e+00,
#          1.51933895e+00,  8.01508388e-01,  9.23851352e-01,
#         -9.96803224e-01,  2.71893800e-01],
#        [-6.16346363e-01, -9.53230755e-01,  5.82681793e-01,
#         -7.16578870e-02, -4.41752437e-02, -1.06750985e+00,
#          7.12455698e-01,  3.20149662e-01],
#        [ 1.70491151e+00, -1.02936378e+00, -1.62856760e+00,
#         -1.14837920e+00,  1.37067449e-01,  1.41406136e+00,
#         -4.02256511e-01, -9.54173681e-02],
#        [-8.41540845e-01, -1.59047385e+00, -1.62856760e+00,
#         -1.48615267e+00, -4.27083297e-01,  1.00704864e-01,
#          5.91474741e-01, -2.35442565e-01],
#        [ 1.66349969e+00, -1.52122584e+00, -1.62856760e+00,
#         -1.37181091e+00, -5.08362266e-01, -7.30891626e-02,
#         -5.44265006e-01, -1.29385524e+00],
#        [ 1.12664867e-01,  1.44284183e+00,  2.54601571e-01,
#          2.54680992e-01, -8.40263620e-01,  1.63487629e+00,
#         -8.51284390e-01,  7.73026846e-01],
#        [ 1.70491151e+00, -1.51481036e-01,  5.82033410e-01,
#          9.67104170e-02,  4.53853323e-01, -1.43835712e+00,
#         -9.48855114e-02,  5.15241001e-01],
#        [ 1.18618732e-01,  6.43600583e-01,  3.10626211e-01,
#          2.74948200e-01, -9.21377302e-01, -7.07261710e-01,
#         -3.88999697e-01, -1.15052956e+00],
#        [ 2.18131121e-01, -2.82749710e-01, -7.34674266e-01,
#         -1.65727751e+00, -1.91661265e+00, -5.82092265e-01,
#         -9.95521827e-01, -3.36177123e-01],
#        [ 7.16844372e-02,  1.30001008e-01,  7.51723517e-01,
#         -1.39187263e+00, -7.10285094e-01, -3.21386025e-01,
#         -1.03522487e+00, -9.01163995e-01],
#        [ 4.58403018e-01,  1.41545262e+00,  1.32716133e-01,
#          1.96278444e+00,  1.16841443e+00,  1.64073768e+00,
#          1.50023156e+00, -1.58972433e+00],
#        [-1.23158774e-01, -5.87009297e-01,  1.58469716e+00,
#         -3.03202123e-01,  1.69214180e+00,  1.55510723e+00,
#          5.84038780e-02,  3.30721219e-01],
#        [-2.77719672e+00,  1.24686405e+00,  1.35740936e+00,
#          1.18721761e+00,  1.32256904e+00,  1.01450791e+00,
#          5.52063910e-01,  5.40608280e-02],
#        [ 1.28662559e+00, -1.56191088e+00, -3.50049539e-01,
#         -9.05558571e-01,  1.73136424e-01,  1.64073768e+00,
#          1.63889967e+00,  4.16857513e-02],
#        [-4.15376496e-02,  2.22100722e-01,  1.02736299e+00,
#          1.00158646e+00,  1.48217958e+00, -9.21084234e-02,
#          3.06221553e-01,  1.52659456e+00],
#        [-1.05991502e+00,  1.02489910e+00,  1.46908649e+00,
#          1.28683585e+00,  1.52999503e+00,  1.64073768e+00,
#          1.63889967e+00,  3.90762916e-01],
#        [-8.23884549e-01, -1.19431523e+00, -2.41531824e-01,
#         -9.16801719e-01, -4.88093083e-01, -7.53944602e-02,
#         -1.32215250e-01, -1.58972433e+00],
#        [-1.23716187e+00, -1.13899101e+00, -7.54112469e-01,
#         -4.02348542e-01,  2.18435904e-01,  4.24755189e-01,
#          7.13455645e-02,  5.01447896e-02],
#        [ 8.97015906e-01, -2.65996705e-01, -2.09435625e-02,
#          4.96710437e-02, -2.55477530e-01,  5.71061607e-02,
#         -1.17370351e+00,  1.52659456e+00],
#        [-2.88651800e-01,  3.93452309e-01, -5.09332472e-01,
#          7.43691287e-01,  2.87993030e-01,  9.74930339e-01,
#         -8.12716433e-01,  1.52659456e+00],
#        [ 2.26693120e-02, -1.54785695e-02, -1.39383551e-01,
#          6.15576837e-01,  3.16531176e-01,  7.11852845e-01,
#         -1.08168252e+00,  9.87636221e-01],
#        [ 1.24914662e+00,  6.65006093e-01,  8.41230668e-01,
#          4.49571914e-01, -7.76636496e-01, -1.34661977e+00,
#         -9.46966586e-01, -1.58972433e+00],
#        [ 7.10089922e-01, -6.79624398e-01,  5.36384158e-01,
#          3.68562999e-01,  8.37757807e-01,  8.16903653e-01,
#          5.16408234e-01,  5.23373504e-01],
#        [-5.77463152e-01,  5.01975114e-01, -3.72683452e-01,
#          3.11355255e-01, -1.30487159e+00,  4.92662625e-01,
#         -1.00524375e+00, -1.62128056e-02],
#        [-7.77015101e-01, -1.36082896e+00, -1.62856760e+00,
#         -1.27649581e+00,  3.07513580e-01, -4.47627158e-01,
#         -3.85614000e-01, -1.12171903e+00],
#        [ 5.95830551e-01, -3.13019713e-01,  6.44424946e-02,
#         -1.01399055e-01,  1.01666901e+00, -2.39698910e-01,
#          4.87163193e-01,  1.40811669e+00],
#        [-3.79873485e-01,  2.89106720e-01,  1.00101454e+00,
#          1.42283419e-01,  3.51187063e-01,  6.60955278e-01,
#         -7.60585284e-01,  1.52659456e+00],
#        [-6.85163122e-01,  1.27371832e+00,  1.34467782e+00,
#          1.17861407e+00,  1.40254364e+00,  7.62808259e-01,
#          9.75756853e-01,  9.74502547e-01],
#        [ 1.03080205e+00,  6.27287805e-01,  4.50744622e-01,
#          9.91780425e-01,  1.04165247e-03,  1.85950373e-01,
#          9.99030448e-01,  1.27181224e+00],
#        [-1.33211584e+00, -5.87675306e-01, -5.18880503e-01,
#          3.86860617e-01,  1.15502599e+00, -1.10495652e-01,
#         -5.26133153e-01,  2.50373293e-01],
#        [-2.21053197e-01,  8.41900507e-01,  1.21893277e+00,
#          1.07777742e+00,  1.27094449e+00, -1.14936403e+00,
#          2.90690496e-01, -1.16692653e+00],
#        [ 6.02107663e-01,  3.00337464e-01, -9.01530412e-01,
#         -2.83574082e-01, -2.34925350e+00,  2.88829083e-01,
#         -4.19330927e-01, -3.26711456e-01],
#        [-1.36368305e+00, -1.12357022e+00, -1.62856760e+00,
#         -2.86663322e-01, -2.24197753e-01,  1.51304970e-01,
#         -9.56555404e-02,  9.41641221e-01],
#        [-7.82700064e-02, -1.79882494e-01,  8.44476841e-01,
#          3.35488505e-02, -1.17952346e+00, -1.30679845e+00,
#         -6.88017407e-01, -1.28297223e+00],
#        [-3.97937566e-02,  1.91578454e+00,  6.56801139e-01,
#          2.77661403e-01,  8.39637541e-01,  1.26851436e+00,
#         -5.90321684e-01, -5.12375210e-01],
#        [-1.35630560e+00, -1.29096542e+00, -1.62856760e+00,
#         -1.32045018e+00, -1.27270182e+00, -2.06135840e-01,
#          1.26079034e+00, -3.29698415e-01],
#        [-6.01146285e-01,  1.44020854e+00,  1.07611859e+00,
#          1.01037000e+00,  7.69856069e-01,  5.06876217e-01,
#          1.54992669e+00,  9.25608316e-01],
#        [-5.30340879e-01,  1.02761522e+00,  8.18697436e-01,
#          1.57455444e+00, -1.11772305e+00, -1.31852099e+00,
#          5.70802617e-02, -1.56505939e-01],
#        [ 1.70491151e+00,  3.26416294e-01, -2.60095328e-01,
#         -2.58797333e-01,  1.17241895e+00,  2.71813878e-01,
#         -5.12887451e-01,  1.50596441e+00],
#        [-2.95903497e-01,  8.25206568e-01,  8.63309252e-01,
#          9.13206622e-01,  1.57633214e-01, -1.36759478e+00,
#         -1.17435726e+00,  1.27586223e+00],
#        [ 1.70491151e+00, -1.40232139e+00, -1.19316991e+00,
#         -1.06956289e+00, -1.21783019e+00,  6.29301043e-01,
#          1.63889967e+00,  3.40408154e-01],
#        [ 1.64487839e+00, -6.85702259e-01, -1.21175231e+00,
#         -5.01450662e-01,  1.16702557e+00,  1.18189698e+00,
#          1.63889967e+00, -8.54676009e-01],
#        [ 8.85096053e-01, -1.41472976e+00,  2.59809977e-02,
#         -1.56887545e+00, -3.53722353e-01,  1.25909676e-01,
#         -3.32216339e-01, -7.17356116e-01],
#        [ 4.96858154e-01,  1.78952448e-01,  2.25015690e-01,
#         -2.18194462e-01, -9.84720958e-01,  6.48394899e-01,
#         -1.49204297e+00,  7.58746702e-01],
#        [ 9.14847307e-01, -4.69777649e-01, -2.31674233e-01,
#         -5.40222732e-01,  9.91140077e-01, -3.33265125e-01,
#         -1.61944372e-01,  1.52659456e+00],
#        [-1.27979499e+00,  1.25778915e+00,  1.30126287e+00,
#          1.30207755e+00,  1.70597065e+00,  1.64073768e+00,
#          1.24046209e+00,  6.26682488e-01],
#        [ 3.63608261e-01,  3.21671913e-01,  3.54150572e-01,
#         -1.89136942e+00,  3.83890020e-01,  1.40222110e-01,
#         -1.19890769e+00, -1.57520958e+00],
#        [-5.62348700e-01,  1.63024551e+00,  1.53172755e+00,
#          1.14759962e+00,  1.79282102e+00,  1.64073768e+00,
#          1.11117382e+00,  8.30109193e-01],
#        [-1.29754337e+00,  1.13879938e+00,  1.46128582e+00,
#          1.17079907e+00,  1.54972572e+00,  1.64073768e+00,
#          1.06857579e-01,  1.15543417e+00],
#        [-5.73681415e-01,  1.14088449e+00,  2.17650120e-01,
#          1.08909658e+00, -2.95822961e-01, -4.30090098e-01,
#          2.95104586e-01,  5.21522747e-01],
#        [ 3.90501915e-02,  4.99978868e-01, -5.48402114e-01,
#         -9.22453402e-01, -7.88539890e-01, -2.74353408e-02,
#         -1.60568888e+00, -1.58972433e+00],
#        [-1.01047904e+00, -3.39464266e-01, -1.55875438e+00,
#         -2.53076045e-01, -1.65782774e-01, -3.69510088e-01,
#         -1.56574841e+00,  8.05286772e-01],
#        [ 1.25262837e+00, -1.77669560e+00, -1.62856760e+00,
#         -1.85705601e+00,  3.38763358e-01, -4.06686228e-01,
#          1.52232268e-01,  1.36691227e+00],
#        [-5.97351499e-01,  7.37281580e-01,  1.13106660e+00,
#          3.09166721e-01, -1.38290748e+00, -1.70455832e+00,
#         -2.09703682e+00,  7.89738386e-01],
#        [-9.66372261e-01, -1.49404642e+00, -1.07730085e+00,
#         -9.39459445e-01,  1.13522912e+00,  1.64073768e+00,
#          3.86227655e-02, -1.58972433e+00],
#        [ 9.73287285e-02,  7.74337749e-02, -2.48626928e-01,
#          3.03650782e-01, -1.78911350e-01, -7.63303552e-01,
#         -7.18275540e-01,  1.10325385e+00],
#        [ 1.70491151e+00, -1.17165777e+00,  5.26958071e-02,
#         -1.84030771e+00, -7.97358602e-01,  1.43727814e-01,
#         -5.74026512e-01,  1.52081183e+00],
#        [ 8.68664002e-01,  9.06543259e-01, -5.99226049e-01,
#          1.38008569e+00, -2.34065789e-01, -7.37521636e-01,
#          7.65474238e-01, -4.80869004e-01],
#        [-9.31478495e-01,  1.94516955e+00,  9.31774869e-01,
#          1.35156128e+00,  1.33139892e+00,  1.64073768e+00,
#          5.35997399e-01, -2.87935855e-01],
#        [-1.11886610e+00, -1.06562392e-01,  1.36413748e+00,
#         -2.82261327e-01, -3.39185039e-02, -1.36481731e+00,
#          9.87782669e-01, -1.58972433e+00],
#        [ 4.27780558e-01,  2.20376411e-02, -9.58790134e-01,
#          7.37172159e-01, -5.53830084e-01, -6.94179494e-01,
#         -7.92035310e-01, -4.57538887e-01],
#        [-1.30277145e+00,  7.10861405e-01,  1.01836065e+00,
#          1.20989388e-02, -4.94010181e-01, -1.29822703e+00,
#         -2.39682847e+00,  4.12356466e-01],
#        [-2.75469146e+00,  1.07078893e+00,  1.28177506e+00,
#          1.29329327e+00,  1.16980353e+00,  1.61398886e+00,
#          1.63889967e+00, -2.87150406e-01],
#        [-6.09692205e-01, -1.24386566e+00, -1.12704116e+00,
#         -1.69336872e+00, -1.26800836e+00, -8.84417311e-01,
#         -3.73078567e-01, -3.51565466e-01],
#        [-2.74172289e-01, -5.34703167e-01, -5.52450746e-01,
#         -1.67199119e+00, -6.41067892e-01, -1.10441500e+00,
#          4.64126201e-01,  1.52659456e+00],
#        [-8.24864304e-01, -1.20512393e+00, -7.17952281e-01,
#         -4.22875761e-01, -3.91107373e-01, -7.76857381e-01,
#          9.08360931e-01, -3.19498539e-01],
#        [ 3.21581713e-02,  5.03809844e-01,  8.76077784e-01,
#          7.28147735e-01,  1.23025518e+00,  1.20205932e+00,
#          9.64171733e-02,  5.17533715e-01],
#        [-5.07837182e-01,  4.23873596e-01,  1.00111956e+00,
#          3.33104176e-01, -4.13353607e-01,  7.97939171e-01,
#         -1.13521776e+00,  8.90328113e-02],
#        [-1.50597880e-01,  6.75752282e-01,  1.89493544e-01,
#          2.72828222e-01,  6.48251268e-01, -1.02709713e-01,
#          9.74655023e-01, -4.90332512e-01],
#        [-8.77972512e-01,  1.24216835e+00,  1.48537276e+00,
#          1.27017856e+00,  1.47547945e+00,  1.64073768e+00,
#          1.63889967e+00,  8.01058280e-01],
#        [-9.40772794e-02,  5.60305722e-01, -9.90392072e-01,
#          6.01196881e-01, -1.13741953e+00, -1.41193206e+00,
#         -1.76469147e+00,  1.43163109e+00],
#        [ 1.70491151e+00,  9.16909001e-01,  7.45916915e-01,
#         -2.30392900e-01,  8.69855750e-01, -1.68091125e+00,
#          8.69650544e-01,  4.00952341e-01],
#        [-4.37990388e-01,  7.49728571e-01,  9.75009258e-01,
#          5.25053935e-01,  5.36453905e-02,  4.36199245e-01,
#         -1.39567418e+00, -1.23992617e+00],
#        [-1.06801808e+00,  4.02398022e-01, -4.09026873e-01,
#         -1.18333294e-01, -4.71643836e-01,  5.24012650e-01,
#         -1.49464066e+00, -2.14127439e-01],
#        [ 7.13936310e-01,  1.24860490e-01, -1.24535995e-01,
#          3.29954528e-01, -6.95012099e-01, -8.74482817e-01,
#          1.30951084e-02, -8.51304362e-01],
#        [-8.29765105e-01, -1.79396018e+00, -1.08131252e+00,
#         -1.33767127e+00,  2.52654150e-01,  4.82034661e-01,
#         -2.74133581e-01, -5.06464944e-01],
#        [ 1.70491151e+00, -3.95139736e-01,  2.01851666e-01,
#         -1.84115865e+00, -8.63377626e-01, -1.28754250e+00,
#         -3.85713560e-01,  8.75938661e-01],
#        [-2.10301866e-01,  6.77644939e-01,  1.24929904e+00,
#          5.53483510e-01,  6.55735170e-01, -1.07114537e+00,
#         -5.36359316e-01, -5.38416266e-01],
#        [-1.17315086e+00,  3.00736000e-02, -1.17829596e+00,
#         -2.20525507e-01, -1.58988408e+00, -7.08556912e-01,
#         -1.10867994e+00, -1.21002002e+00],
#        [ 6.04459821e-01,  2.71006421e-01, -5.47178536e-01,
#          2.79092725e-01, -1.54129269e+00,  3.43664885e-01,
#         -5.99297071e-01,  1.82551582e-02],
#        [ 1.70491151e+00, -1.89495386e+00, -1.62856760e+00,
#         -1.52569971e+00, -1.84990313e+00, -1.60247236e-01,
#         -2.40782878e-01, -6.18318006e-01],
#        [-2.61528791e-01,  9.04499233e-01,  1.37196585e+00,
#          1.15948433e+00,  1.23050217e+00,  2.66627837e-01,
#          1.63889967e+00, -1.08168388e+00],
#        [-7.99434618e-01, -1.52211555e+00, -1.46479167e+00,
#         -8.07172098e-01, -1.49449844e+00, -4.30824703e-01,
#         -8.49775720e-02, -5.74212410e-01],
#        [ 1.98021103e-01, -1.19489828e+00, -1.40600547e-01,
#         -9.86627246e-01, -1.30359031e-01, -7.88143304e-01,
#          1.34484449e+00, -7.35693720e-01],
#        [ 2.22312416e-01, -2.56886971e-01, -1.06424986e+00,
#          3.02310179e-01, -1.46055864e+00, -1.12838611e+00,
#         -1.48831716e+00, -8.02617216e-01],
#        [ 2.76410239e-01,  3.71109758e-01,  3.61413565e-01,
#          4.87980805e-01, -8.67573585e-01, -1.73931861e+00,
#         -1.04080405e+00, -1.58972433e+00],
#        [-1.62139365e-01, -1.51649125e+00,  4.92630679e-01,
#         -1.22051509e+00,  1.12546023e-01, -5.59694000e-01,
#          6.27696906e-01, -1.58972433e+00],
#        [-1.86176010e-01, -1.39345665e+00,  1.44385091e-02,
#         -1.23172650e+00, -1.13864413e+00, -4.37444998e-01,
#         -3.13535875e-01,  7.79890956e-01]])

# %%
x_test
# Out:
# array([[ 0.36360826, -0.41157251,  0.02551892, -0.37222669,  1.41196302,
#          0.11730257,  0.25963488, -0.81546881],
#        [-0.11786144, -0.78852854, -1.41917917, -1.03095908, -0.56400681,
#         -0.47078699, -1.34543369, -0.39916853],
#        [-0.65736307, -1.55737966, -1.6285676 , -0.89939076, -0.04603201,
#          0.42229449,  0.19792382,  0.79461577],
#        [ 0.25482871,  0.77231256,  0.52404859,  1.0884508 ,  0.53053568,
#         -1.69434377, -0.84991904, -1.58972433],
#        [-0.14439175,  0.40707434, -0.97570792,  0.88288265, -0.66685027,
#         -1.00453675, -0.03503584, -1.28510057],
#        [-0.28955783,  0.22915817,  0.96857271, -0.54154648,  0.24674668,
#          1.55598452, -0.51409996, -0.52820142],
#        [-0.63920942, -0.67673613, -0.06572038, -0.21560251, -0.73395791,
#         -1.57956487, -0.12178127,  1.52659456],
#        [ 0.25066962, -1.45937382, -1.00402536, -1.14765326, -1.29941146,
#          0.86466447, -0.46754054, -0.31532118],
#        [-0.24800913, -0.32196754, -1.6285676 ,  0.29913419, -0.24039117,
#          1.64073768, -1.75270891, -1.2200918 ],
#        [-0.65736307,  1.81808901, -0.04416975,  2.04474183,  0.74258947,
#          1.64073768,  0.80596945, -0.49130362],
#        [-0.20672202,  0.79724435,  1.1981731 ,  0.60635782, -0.7983175 ,
#         -1.21632543, -0.52279454,  0.35084756],
#        [-1.66255044,  1.25124447,  1.25302779,  1.19308059,  1.33081553,
#          1.60224426,  1.63889967,  0.83094419],
#        [ 1.58597352,  0.45478986, -0.62967257,  0.50049474, -0.59547983,
#         -1.788608  , -0.84687401, -0.37955324],
#        [-0.09407728, -0.66688821, -0.4621304 , -0.02965585, -1.21378542,
#          0.19007209, -1.11300721, -0.11274433],
#        [ 0.30616619,  0.13010489, -0.0913804 ,  0.39497312, -1.44716576,
#         -1.37454806, -0.28947904, -0.15692898],
#        [ 0.15084047, -1.06869217, -0.62222193, -1.50116128,  0.37023237,
#         -0.79696883, -0.1539936 , -0.33302093],
#        [-1.88820943, -0.10636009,  0.26965548, -0.1295185 ,  0.17520159,
#         -1.93571068,  1.63889967, -0.54246603],
#        [ 1.26514325, -1.8935916 , -1.6285676 , -1.52167936, -0.07319967,
#         -0.60466671,  0.97914618,  1.52659456],
#        [-0.84252304,  0.02835283, -1.6285676 ,  0.34236688, -1.11593312,
#         -0.70305619, -1.65051962,  0.07469946],
#        [-0.70632711,  1.53640373,  0.4570226 ,  0.71532423,  1.54869965,
#          1.64073768,  0.39127189,  0.35317599],
#        [ 0.01921527,  0.08205688,  0.11275312,  0.13927931, -0.23479855,
#          0.34334518, -1.13445843, -0.50357186],
#        [ 1.70491151, -1.79055148, -1.01584209, -1.21058393, -0.98748545,
#         -0.72349237,  0.20136402,  1.47845039],
#        [-0.49941745, -0.99856107, -0.69912569, -1.16095021, -1.2283611 ,
#          0.65550474, -0.03064038,  0.05875814],
#        [-0.35969701,  1.00915231, -0.32286641,  1.64482733, -0.71022409,
#         -0.47033978, -0.35609526,  0.29109648],
#        [-1.10357471,  1.23983557,  1.69827202,  1.08522306,  1.6157332 ,
#          1.64073768,  1.06435302,  0.88719009],
#        [ 0.90965247,  0.90634724,  0.18878396,  1.38008569,  0.349578  ,
#          0.34195924,  0.36769721, -1.21103717],
#        [ 0.09476903,  0.4818416 ,  1.08205361,  0.59683856,  0.05965761,
#         -0.37843203, -1.09139208,  1.52659456],
#        [-1.20921847, -0.25139634,  0.35081199, -0.40120638,  0.66215611,
#          0.46261947,  1.63889967, -1.10968121],
#        [ 0.47285316, -0.98444427, -1.60514599, -0.24623167,  1.72915363,
#         -0.562773  ,  1.56997216, -1.58972433],
#        [-0.34506148,  0.669391  ,  0.44065195, -0.10394438,  0.54406255,
#         -0.38275971, -1.05089846,  0.35286257],
#        [ 0.91929611, -0.67476296, -0.34149667,  0.13313527, -0.26886928,
#         -0.62852187,  0.07634693, -0.59116478],
#        [-1.019534  ,  1.44606101,  1.63571005,  1.4917645 ,  1.75633466,
#          1.64073768,  0.68160602,  0.94102664],
#        [ 1.70491151, -0.09634008, -0.48955077,  0.6158969 , -1.96746369,
#         -1.88363102,  0.24272298, -0.06644003],
#        [-0.75757765,  1.27005165,  1.74886469,  1.20800574,  1.34758354,
#          1.4465499 ,  1.63889967, -0.27345038],
#        [-0.15592216, -1.42014714, -0.76934576, -1.40667297, -0.31207883,
#          0.18170623, -0.0452688 , -1.56674047],
#        [ 1.70491151,  0.06499667,  0.68747412,  0.00744628,  1.01178085,
#          0.33704779, -0.05129956, -1.58972433],
#        [ 0.46723787,  0.75613695, -0.44605535,  1.12934838, -2.03512698,
#         -1.62573642, -2.42169718, -0.69731725],
#        [ 0.32263422,  1.17332111,  1.93730033,  1.53234847,  1.43994643,
#          0.32751263,  1.63889967,  1.32547197],
#        [ 0.05281161, -0.27762341,  1.38698441, -0.02587128,  0.71534623,
#         -0.41354035,  1.07281717,  0.22146727],
#        [-0.85038547,  1.08320593,  1.12930757,  1.81364264,  0.392716  ,
#          0.70920468, -1.17228723, -0.99058225]])

# %%
y_test
# Out:
# 89     5.073
# 135    4.077
# 121    4.512
# 87     5.102
# 102    4.839
# 69     5.548
# 51     5.889
# 139    3.956
# 129    4.297
# 23     6.798
# 44     5.995
# 6      7.378
# 85     5.124
# 107    4.715
# 86     5.123
# 132    4.252
# 73     5.399
# 130    4.292
# 106    4.739
# 19     6.901
# 81     5.192
# 115    4.571
# 123    4.436
# 46     5.984
# 2      7.527
# 65     5.695
# 29     6.574
# 78     5.253
# 144    3.819
# 53     5.855
# 104    4.788
# 0      7.587
# 95     4.949
# 17     6.940
# 151    3.587
# 97     4.885
# 101    4.857
# 1      7.561
# 52     5.878
# 45     5.987
# Name: Happiness Score, dtype: float64

# %%
y_train
# Out:
# 128    4.307
# 18     6.937
# 109    4.686
# 80     5.194
# 83     5.140
#        ...
# 124    4.419
# 126    4.350
# 133    4.218
# 140    3.931
# 114    4.610
# Name: Happiness Score, Length: 118, dtype: float64

# %% [markdown]
# # Linear Regression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
prediction_lr = lr.predict(x_test)
r2_score(y_test,prediction_lr)
# Out:
# 0.9828788584906023

# %% [markdown]
# # Decision Tree

# %%
DT = DecisionTreeRegressor()
DT.fit(x_train,y_train)
prediction_DT = DT.predict(x_test)
r2_score(y_test,prediction_DT)
# Out:
# 0.6008672011412401

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred_rf = rf.predict(x_test)
r2_score(y_test,y_pred_rf)
# Out:
# 0.9349070465042812

# %%
rf
# Out:
# RandomForestRegressor()

# %% [markdown]
# # Ada Boost

# %%
ada = AdaBoostRegressor()
ada.fit(x_train,y_train)
y_pred = ada.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.9119950076992881

# %% [markdown]
# # Gradient Boosting

# %%
gbt = GradientBoostingRegressor()
gbt.fit(x_train,y_train)
y_pred = gbt.predict(x_test)
print(y_pred)
r2_score(y_test,y_pred)
# Out:
# [4.85355993 4.04459493 4.37915521 5.44504632 4.85818856 5.37643632
#  5.83985172 3.85137038 4.16087115 5.98028203 5.78730537 7.35930377
#  4.85760687 5.30952535 5.13575084 4.14129157 5.19582501 4.49022718
#  4.99582528 7.06306912 5.22862327 4.5884764  4.58787116 5.93320253
#  7.42233171 5.85558341 6.76105604 5.05874851 3.72705734 6.08833465
#  5.01037598 7.31003007 5.17755932 6.90223727 3.7678592  5.06090108
#  5.37935996 7.30850662 5.87500636 5.99948574]
# 0.9492135249402539

# %%
gbtcross = cross_val_score(gbt,x_train,y_train,cv=5)
print(gbtcross)
print(gbtcross.mean())
# Out:
# [0.87383714 0.82238561 0.86470928 0.86259497 0.9441534 ]
# 0.8735360796809113

# %%
gbt
# Out:
# GradientBoostingRegressor()

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import GradientBoostingRegressor
parameters={'loss':['ls','lad','huber','quantile'],'n_estimators':[50,100,200,300],'learning_rate':[0.1,1,0.001]}
gbc=GridSearchCV(gbt,parameters)
gbc.fit(x_train,y_train)
print(gbc.best_params_)
# Out:
# {'learning_rate': 0.1, 'loss': 'huber', 'n_estimators': 200}

# %%
gbt=GradientBoostingRegressor(loss='huber',n_estimators=200,learning_rate=0.1)
gbt.fit(x_train,y_train)
gbt_predict=gbt.predict(x_test)
gbts=r2_score(y_test,gbt_predict)*100
print("r2 score=",gbts)
gbtscore=cross_val_score(gbt,x_test,y_test,cv=5).mean()*100
print('cross val score=',gbtscore)
# Out:
# r2 score= 95.24450616142443
# cross val score= 84.89500004718539

# %%
print("Gradient Boost")
from sklearn.metrics import mean_absolute_error,mean_squared_error

print("mean absolute error i=",mean_absolute_error(y_test,gbt_predict))
print("mean squared error is=",mean_squared_error(y_test,gbt_predict))
print("Root mean square error(RMSE)=",np.sqrt(mean_squared_error(y_test,gbt_predict)))
# Out:
# Gradient Boost
# mean absolute error i= 0.1820903060396099
# mean squared error is= 0.054963445078985075
# Root mean square error(RMSE)= 0.23444283968375976

# %% [markdown]
# Save the model

# %%
import joblib

# %%
 
filename="World_Happiness_Report.pkl"
joblib.dump(gbt,filename)
# Out:
# ['World_Happiness_Report.pkl']

# %%
load_model = joblib.load(filename)
load_model
# Out:
# GradientBoostingRegressor(loss='huber', n_estimators=200)

# %%
X.columns
# Out:
# Index(['Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# Testing with unseen data

# %%
input_data = (0.03411,1.39651,1.34951,0.94143,0.66557,0.41978,0.29678,2.51738)

# %%
# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)
input_data_as_numpy_array.shape
# Out:
# (8,)

# %%
# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
input_data_reshaped.shape
# Out:
# (1, 8)

# %%
prediction = load_model.predict(input_data_reshaped)
prediction[0]
# Out:
# 7.187896491894078

# %%
X
# Out:
#      Standard Error  Economy (GDP per Capita)    Family  \
# 0          0.034110                   1.39651  1.349510
# 1          0.048840                   1.30232  1.402230
# 2          0.033280                   1.32548  1.360580
# 3          0.038800                   1.45900  1.330950
# 4          0.035530                   1.32629  1.322610
# ..              ...                       ...       ...
# 153        0.034640                   0.22208  0.773700
# 154        0.036560                   0.28665  0.620439
# 155        0.050150                   0.66320  0.620439
# 156        0.067919                   0.01530  0.620439
# 157        0.067270                   0.20868  0.620439
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                       0.326539
# 1                     0.94784  0.62877                       0.141450
# 2                     0.87464  0.64938                       0.326539
# 3                     0.88521  0.66973                       0.326539
# 4                     0.90563  0.63297                       0.326539
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                       0.326539
# 154                   0.31910  0.48450                       0.080100
# 155                   0.72193  0.15684                       0.189060
# 156                   0.22396  0.11850                       0.100620
# 157                   0.28443  0.36453                       0.107310
#
#      Generosity  Dystopia Residual
# 0      0.296780           2.517380
# 1      0.412372           2.702010
# 2      0.341390           2.492040
# 3      0.346990           2.465310
# 4      0.412372           2.451760
# ..          ...                ...
# 153    0.226280           1.456452
# 154    0.182600           1.633280
# 155    0.412372           1.456452
# 156    0.197270           1.833020
# 157    0.166810           1.567260
#
# [158 rows x 8 columns]
